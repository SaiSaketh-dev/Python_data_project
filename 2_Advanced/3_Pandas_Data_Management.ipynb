# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset


dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample() #sample is similar to .head() and .tail(), the number if we want a defined number of sample, we should give a value inside the parenthesis as shown in the example below
# Out:
#        job_title_short                   job_title job_location       job_via  \
# 337636  Data Scientist  Data Lead - Data Scientist     Anywhere  via LinkedIn
#
#        job_schedule_type  job_work_from_home search_location  \
# 337636         Full-time                True         Georgia
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 337636 2023-06-08 23:47:06                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 337636  United States        None              NaN              NaN
#
#                company_name  \
# 337636  Index Analytics LLC
#
#                                                job_skills  \
# 337636  ['python', 'r', 'matlab', 'aws', 'redshift', '...
#
#                                           job_type_skills
# 337636  {'cloud': ['aws', 'redshift'], 'libraries': ['...

# %%
df.sample(10, random_state=1) # random state is used to fix the values. The number assigned to random state can be anything
# Out:
#               job_title_short                      job_title  \
# 303776          Data Engineer           Data Center Engineer
# 330513  Senior Data Scientist  Big Data Senior - Remote Work
# 237202         Data Scientist              Database Engineer
# 539858          Data Engineer            Spark Data Engineer
# 618796         Data Scientist   Environmental Data Scientist
# 392419   Senior Data Engineer           Senior Data Engineer
# 657919           Data Analyst                   Data Analyst
# 470055       Business Analyst             Contract Analyst I
# 65015          Data Scientist        Data Scientist - Senior
# 24727           Data Engineer                  Data Engineer
#
#                        job_location                job_via job_schedule_type  \
# 303776                    Singapore    via BeBee Singapore         Full-time
# 330513             Machala, Ecuador           via Sercanto         Full-time
# ...

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

df_original['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_altered = df_original

# %%
id(df_altered) ==id(df_original)
# Out:
# True

# %%
df_altered = df_original.copy()

# %%
id(df_altered) ==id(df_original)
# Out:
# False

# %%
median_hour_salary = df_altered['salary_hour_avg'].median()

# %%
df_altered['salary_hour_avg'] = df['salary_hour_avg'].fillna(median_hour_salary)

# %%
df_altered
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_original
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...
